# %% [markdown]
# ### Data Cleaning
#
# **Scenario:**
# Imagine you are preparing a dataset of images to feed into an AI model (like a Convolutional Neural Network or CNN). The raw data received from the camera sensor is stored as a list of numbers (pixel values), but unfortunately, the sensor introduced some noise and calculation errors.
#
# **Your Mission:**
# You need to write a script that inspects and cleans this raw data.
# Fill in the blanks (`___`) in the code cell below. Pay attention to nested functions, correct list methods, and Python's specific identity operators:
#
# 1. **Input & Casting:** Ask the user to input the maximum allowed value and convert it to an integer in a *single line*.
# 2. **Iteration & Flow Control:** Loop through each pixel and apply conditions. If a number is negative, flag the error and bypass the current iteration immediately.
# 3. **List Manipulation:** If the data is out-of-bounds, cap it. Otherwise, keep it. You must use the correct method to insert these values into your new list.
# 4. **Identity Check:** Use Python's identity operator (not the equality operator `==`) to check the status of your boolean flag at the end.

# %%
# 1. Input, Output & Type Casting
# TODO: Get user input AND convert it to an integer simultaneously.
max_val = ___(___("Enter maximum pixel value (e.g., 255): "))

# 2. Variables & Built-in Functions
# TODO: Initialize the boolean flag properly (Mind the capitalization).
has_error = ___ 

raw_pixels = [120, -15, 256, 100, 310, 45, 0, -5, 200]

# TODO: Create an empty list using Python's built-in function (do not use [])
processed_pixels = ___()

# 3. Loops, Conditionals & List Methods
# TODO: Set up the correct iteration syntax.
___ pixel ___ raw_pixels:
    
    # Check for negative values (corrupted data)
    ___ pixel < 0:
        print("Warning: Negative value detected! Skipping...")
        has_error = ___
        # TODO: Use the exact keyword to skip the rest of THIS loop iteration.
        ___
        
    # Check if the pixel value exceeds the maximum limit
    ___ pixel > max_val: 
        # TODO: Use the correct list method to add the capped value.
        processed_pixels.___(max_val)
        
    # For all other normal values
    ___:
        # TODO: Use the correct list method to add the original pixel.
        processed_pixels.___(pixel)

# 4. Final Output & Identity Operators
# TODO: Check if 'has_error' is EXACTLY the True object. 
# Hint: Use Python's identity operator, do NOT use the '==' operator.
if has_error ___ True: 
    print("Process finished: Corrupted data was found and removed.")
else:
    print("Process finished: All data was originally clean.")

# Print the final result
print("Processed Data:", processed_pixels)

# %% [markdown]
# ### Data Normalization Pipeline (Advanced Functions)
#
# **Scenario:**
# In machine learning, numerical features are often transformed into a range between 0 and 1. This helps the model train faster and prevents larger numbers from dominating the AI's learning process.
# The basic formula for Min-Max Normalization is: `(current_value - min_value) / (max_value - min_value)`
#
# **Your Mission:**
# You need to build a highly flexible processing pipeline. Fill in the blanks (`___`) in the code cell below. Pay attention to default parameters, scope definitions, higher-order functions, and arbitrary arguments packing/unpacking (`*args`):
#
# 1. **Default Arguments:** Define the scaling function and assign default safety values to its parameters.
# 2. **Global Variables:** Explicitly declare the use of a global counter inside your manager function so you can modify it.
# 3. **Higher-Order Functions & `*args`:** Your manager function (`process_data`) should be smart enough to accept *any* transformation function, plus a flexible number of extra arguments (`*args`) to pass down to that specific function.
# 4. **Execution:** Pass the math function *by reference* (without executing it) into the manager.

# %%
transformation_count = 0

# 1. Defining a Function with Default Arguments
# TODO: Define 'min_max_scale'. Assign a default value of 0 to min_val and 100 to max_val.
___ min_max_scale(value, min_val___0, max_val___100):
    
    scaled = (value - min_val) / (max_val - min_val)
    
    # TODO: Output the calculated value
    ___ scaled


# 2. Higher-Order Functions & *args (Arbitrary Arguments)
# TODO: Define 'process_data'. It takes a list, a function, and any number of extra positional arguments.
def process_data(data_list, transform_func, ___):
    
    # TODO: Declare that we are modifying the GLOBAL counter variable defined at the top
    ___ transformation_count
    
    result_list = []
    
    for item in data_list:
        # TODO: Call the passed function on 'item' and UNPACK the extra arguments here
        new_item = ___(item, ___)
        result_list.append(new_item)
        
    # TODO: Use the correct assignment operator to increment the counter by 1
    transformation_count ___ 1
    
    return result_list


# --- Main Execution ---
raw_data = [20, 50, 80, 10]
data_min = 10  # Actual minimum in our dataset
data_max = 80  # Actual maximum in our dataset

# 3. Execution
# TODO: Call 'process_data'. 
# Pass 'raw_data', the 'min_max_scale' function ITSELF (not its result!), and the min/max limits.
normalized_data = process_data(raw_data, ___, data_min, data_max)


# Output the results
print("Original Data:", raw_data)
print("Normalized Data:", normalized_data)
print("Total Pipeline Executions:", transformation_count)

# %% [markdown]
# ### Model Configuration & Metadata (Data Structures)
#
# **Scenario:**
# Before training an AI model, you need to set up its configuration parameters, define the input data shapes, and process dataset labels. Python's built-in data structures are perfect for these tasks.
#
# **Your Mission:**
# Fill in the blanks (`___`) in the code below to correctly utilize Tuples, Dictionaries, Sets, and List Comprehensions:
#
# 1. **Tuples:** Define the fixed input dimensions of an image. Tuples are immutable, making them safe for fixed configurations.
# 2. **Dictionaries:** Create a configuration profile for the AI model using key-value pairs, and then update one of its hyperparameters.
# 3. **Sets:** You have a list containing thousands of image labels with many duplicates. Convert it to a Set to instantly find the unique categories.
# 4. **Strings & List Comprehension:** Use Python's powerful one-liner (list comprehension) to clean up a list of file names by removing their file extensions.

# %%
# 1. TUPLES (Immutable Data)
# TODO: Create a tuple representing an image shape: Height=224, Width=224, Channels=3
image_shape = ___(224, 224, 3___ 


# 2. DICTIONARIES (Key-Value Pairs)
# TODO: Create a dictionary to store model hyperparameters.
model_config = ___
    "learning_rate": 0.001,
    "batch_size": 32,
    "optimizer": "Adam"
___

# TODO: The dataset is too large! Update the "batch_size" value to 64.
model_config___"batch_size"___ = 64


# 3. SETS (Unique Elements)
# This list simulates labels from a dataset, which contains duplicate entries.
raw_labels = ["cat", "dog", "cat", "bird", "dog", "cat", "bird"]

# TODO: Convert the 'raw_labels' list into a set to extract only the unique classes.
unique_classes = ___(raw_labels)


# 4. STRINGS & LIST COMPREHENSION
# We have a list of image filenames, but we only want the names without the ".jpg" extension.
image_files = ["image_01.jpg", "image_02.jpg", "image_03.jpg"]

# TODO: Use list comprehension to remove the extension. 
clean_names = [file.___(".jpg", "") ___ file ___ image_files]


# --- Check Your Results ---
print("Model Input Shape:", image_shape)
print("Updated Config:", model_config)
print("Unique Classes:", unique_classes)
print("Cleaned File Names:", clean_names)

# %% [markdown]
# ### Building a Model Blueprint (OOP Basics)
#
# **Scenario:**
# In modern AI frameworks (like PyTorch or TensorFlow), neural networks and machine learning models are heavily based on Object-Oriented Programming (OOP). You don't just write loose functions; instead, you create a `Class` (a blueprint) for your model, and then generate `Objects` (instances) from that blueprint.
#
# **Your Mission:**
# You are going to define a blueprint for a basic Machine Learning model.
# Fill in the blanks (`___`) in the code below to implement the core OOP concepts:
#
# 1. **Classes:** Define a new class named `SimpleModel`.
# 2. **Constructors & `self`:** Use the special `__init__` method to initialize the model's attributes (like its name and learning rate) when an object is created. Remember that `self` is required to attach these variables to the object.
# 3. **Objects:** Create an actual instance (object) of your model.
# 4. **Methods:** Call the `train` method on your newly created object.

# %%
# 1. Defining the Class
# TODO: Use the correct keyword to define a blueprint named SimpleModel.
___ SimpleModel:
    
    # 2. The Constructor and 'self'
    # TODO: Define constructor.
    def ___(self, model_name, learning_rate):
        
        # TODO: Attach the arguments to the object using the 'self' keyword.
        ___.name = model_name
        ___.lr = learning_rate
        ---.is_trained = False
        print(f"Model '{self.name}' created with Learning Rate: {self.lr}")

    # A simple method belonging to the class
    # TODO: All instance methods must take a specific first parameter.
    def train(___, epochs):
        print(f"Training '{self.name}' for {epochs} epochs...")
        self.is_trained = True
        print("Training complete!")


# 3. Creating an Object
# TODO: Instantiate an object from the blueprint you just created.
# Name the model "VisionNet" and set the learning rate to 0.001.
my_ai_model = ___("VisionNet", ___)

# 4. Using the Object
# TODO: Call the 'train' method on your newly created object and pass 10 as the number of epochs.
my_ai_model.___(___)

# Check the object's attribute to see if it changed
print("Is the model trained?", my_ai_model.is_trained)

# %% [markdown]
# ### Saving Training Logs (File Handling)
#
# **Scenario:**
# When training an AI model, the process can take hours or even days. If you don't save the model's performance metrics (like accuracy and loss) to a file, all that information is lost as soon as the program finishes running!
#
# **Your Mission:**
# You have a list of training logs. You need to write these logs to a text file on your hard drive, and then read the file back to verify the contents.
# Fill in the blanks (`___`) in the code below to handle file reading and writing safely:
#
# 1. **Write Mode (`"w"`):** Open a file in write mode to create it (or overwrite it if it exists) and save the logs line by line.
# 2. **Context Managers (`with`):** Always use the `with` keyword when opening files. It acts as a safety mechanism that automatically closes the file for you when the block of code finishes, even if an error occurs.
# 3. **Read Mode (`"r"`):** Open the newly created file in read mode and extract its contents to display them on the screen.

# %%
# A list of strings representing our model's performance over 3 epochs
training_logs = [
    "Epoch 1: Accuracy = 0.75, Loss = 0.50\n",
    "Epoch 2: Accuracy = 0.82, Loss = 0.40\n",
    "Epoch 3: Accuracy = 0.89, Loss = 0.30\n"
]

# 1. Writing to a File
___ ___("metrics.txt", "___") as file:
    
    for log in training_logs:
        # TODO: Use the correct file method to write the string into the file.
        file.___(log)
        
print("Logs successfully saved to 'metrics.txt'!")


# 2. Reading from a File
# TODO: Open the exact same file, but this time in Read mode.
___ ___("metrics.txt", "___") ___ file:
    
    # TODO: Use the correct file method to read the ENTIRE content of the file at once.
    saved_content = file.___()
    
    print("\n--- Displaying Saved Logs ---")
    print(saved_content)
